# %%
import jieba
import multidict as multidict
import matplotlib.pyplot as plt
from time import time
from wordcloud import WordCloud

# %%
# Load user defined words
user_dict_path = "../userdict.txt"
jieba.load_userdict(user_dict_path)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache D:\MyData\XUGP3\AppData\Local\Temp\jieba.cache
# Loading model cost 1.220 seconds.
# Prefix dict has been built succesfully.

# %%
def load_data(filepath):
    text = list()
    with open(filepath, 'r', encoding='utf-8') as fin:
        lines = fin.read().splitlines()
        for line in lines:
            text.extend(line.split('\t'))
    return text

# %%
def load_stopwords(filepath):
    with open(filepath, 'r', encoding='utf-8') as fin:
        lines = fin.read().splitlines()
        stopwords = [line.strip().lower() for line in lines]
        stopwords = list(set(stopwords))  # remove duplicate
    return stopwords

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        pass
 
    try:
        import unicodedata
        unicodedata.numeric(s)
        return True
    except (TypeError, ValueError):
        pass
 
    return False

# %%
def get_frequency_dict(data, stopwords=[]):
    full_terms_dict = multidict.MultiDict()
    temp_dict = {}
    
    for text in data:
        text = text.strip().lower()
        words = list(jieba.cut(text))
        for word in words:
            # filter single characters
            if len(word) < 2:
                continue
            
            # filter number
            if is_number(word):
                continue
            
            if word not in stopwords:
                freq = temp_dict.get(word, 0)
                temp_dict[word] = freq + 1
                
    for key in temp_dict:
        full_terms_dict.add(key, temp_dict[key])
        
    return full_terms_dict

# %%
def get_frequency_dict_v2(data, stopwords=[]):
    freq_dict = {}
    for text in data:
        text = text.strip().lower()
        words = list(jieba.cut(text))
        for word in words:
            # filter the single characters
            if len(word) < 2:
                continue
                
            # filter number
            if is_number(word):
                continue
            
            if word not in stopwords:
                freq = freq_dict.get(word, 0)
                freq_dict[word] = freq + 1
        
    return freq_dict

# %%
# 1. 载入数据
data_path = "../text.txt"
data = load_data(data_path)

# %%
# 2. 加载停用词
stopwords_path = "../stopwords.txt"
stopwords = load_stopwords(stopwords_path)

# %%
# 3. 计算词频
t0_count = time()
freq_dict = get_frequency_dict_v2(data, stopwords=stopwords)
print("Done in %.3f seconds." % (time() - t0_count))
# Out:
# Done in 115.271 seconds.

# %%
# Optional procedure
freq_dict_copyed = freq_dict.copy()
freq_dict = dict()
for key in freq_dict_copyed:
    words = list(freq_dict_copyed.keys())
    words.remove(key)
    words_str = '|'.join(words)
    if key not in words_str:
        freq_dict[key] = freq_dict_copyed[key]

# %%
# 4. 绘图
font_path = "../SourceHanSerifK-Light.otf"
wc = WordCloud(font_path=font_path, 
               max_words=50, 
               width=1000, 
               height=860, 
               background_color='white', 
               random_state=42)
wc.generate_from_frequencies(freq_dict)

plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

wordcloud_path = "../wordcloud_50_2.png"
wc.to_file(wordcloud_path)
